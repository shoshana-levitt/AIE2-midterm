# %%
# !pip install -U -q langchain langchain-openai langchain_core langchain-community langchainhub openai
# !pip install -qU ragas
# !pip install -qU qdrant-client pymupdf pandas

# %%
import os
import openai
from getpass import getpass

openai.api_key = getpass("Please provide your OpenAI Key: ")
os.environ["OPENAI_API_KEY"] = openai.api_key

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader(
    "/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf",
)

documents = loader.load()

# %%
documents[0].metadata
# Out:
# {'source': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf',
#  'file_path': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf',
#  'page': 0,
#  'total_pages': 147,
#  'format': 'PDF 1.4',
#  'title': '0001326801-24-000012',
#  'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group',
#  'subject': 'Form 10-K filed on 2024-02-02 for the period ending 2023-12-31',
#  'keywords': '0001326801-24-000012; ; 10-K',
#  'creator': 'EDGAR Filing HTML Converter',
#  'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0',
#  'creationDate': "D:20240202060356-05'00'",
#  'modDate': "D:20240202060413-05'00'",
#  'trapped': '',
#  'encryption': 'Standard V2 R3 128-bit RC4'}

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 200,
    chunk_overlap = 50
)

documents = text_splitter.split_documents(documents)

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small"
)

# %%
from langchain_community.vectorstores import Qdrant

qdrant_vector_store = Qdrant.from_documents(
    documents,
    embeddings,
    location=":memory:",
    collection_name="meta-10-k-filings",
)

# %%
retriever = qdrant_vector_store.as_retriever()

# %%
retrieved_documents = retriever.invoke("What was the total value of 'Cash and cash equivalents' as of December 31, 2023?")
retrieved_documents = retriever.invoke("Who are Meta's 'Directors' (i.e., members of the Board of Directors)?")

# %%
for doc in retrieved_documents:
  print(doc)
# Out:
# page_content='on the Nasdaq Global Select Market under the symbol "META." Our principal executive offices are located at 1 Meta Way, Menlo Park, California 94025, and\nour telephone number is (650) 543-4800.' metadata={'source': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf', 'file_path': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf', 'page': 13, 'total_pages': 147, 'format': 'PDF 1.4', 'title': '0001326801-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-02 for the period ending 2023-12-31', 'keywords': '0001326801-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240202060356-05'00'", 'modDate': "D:20240202060413-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'a5851c4498684b1ebed0ba7d48333205', '_collection_name': 'meta-10-k-filings'}
# page_content='Unless expressly indicated or the context requires otherwise, the terms "Meta," "company," "we," "us," and "our" in this document refer to Meta' metadata={'source': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf', 'file_path': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf', 'page': 3, 'total_pages': 147, 'format': 'PDF 1.4', 'title': '0001326801-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-02 for the period ending 2023-12-31', 'keywords': '0001326801-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240202060356-05'00'", 'modDate': "D:20240202060413-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '77e2432ccf3f4cafbedc3483a5114df5', '_collection_name': 'meta-10-k-filings'}
# page_content='Committee of the Board of Directors (the “Board”) of Meta Platforms, Inc. (the “Company”) on June 1, 2023. This Policy provides for the recoupment of' metadata={'source': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf', 'file_path': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf', 'page': 143, 'total_pages': 147, 'format': 'PDF 1.4', 'title': '0001326801-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-02 for the period ending 2023-12-31', 'keywords': '0001326801-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240202060356-05'00'", 'modDate': "D:20240202060413-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '29b49714f92d4c2b9d37888c6ec0104d', '_collection_name': 'meta-10-k-filings'}
# page_content='Meta.com. These efforts are focused on driving consumer and enterprise sales and adoption of our Meta Quest portfolio of products and Ray-Ban Meta smart\nglasses.\nMarketing' metadata={'source': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf', 'file_path': '/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf', 'page': 9, 'total_pages': 147, 'format': 'PDF 1.4', 'title': '0001326801-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-02 for the period ending 2023-12-31', 'keywords': '0001326801-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240202060356-05'00'", 'modDate': "D:20240202060413-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '6a4a5c2d037847848fde90c8fdf93950', '_collection_name': 'meta-10-k-filings'}

# %%
from langchain import hub

retrieval_qa_prompt = hub.pull("langchain-ai/retrieval-qa-chat")

# %%
from langchain.prompts import ChatPromptTemplate

template = """Answer the question based only on the following context. If you cannot answer the question with the context, please respond with 'I don't know':

Context:
{context}

Question:
{question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
from operator import itemgetter

from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

primary_qa_llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

retrieval_augmented_qa_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": prompt | primary_qa_llm, "context": itemgetter("context")}
)

# %%
questions = ["What was the total value of 'Cash and cash equivalents' as of December 31, 2023?", "Who are Meta's 'Directors' (i.e., members of the Board of Directors)"]

for question in questions:
  answer = retrieval_augmented_qa_chain.invoke({"question" : question})["response"].content
  print(f"Question: {question} / Answer: {answer}")
# Out:
# Question: What was the total value of 'Cash and cash equivalents' as of December 31, 2023? / Answer: $41,862 billion
# Question: Who are Meta's 'Directors' (i.e., members of the Board of Directors) / Answer: I don't know.

# %%
loader = PyMuPDFLoader(
    "/Users/SKTL/Desktop/Coding/VS-Code/AIE2-midterm/meta_pdf.pdf",
)

eval_documents = loader.load()

text_splitter_eval = RecursiveCharacterTextSplitter(
    chunk_size = 600,
    chunk_overlap = 50
)

eval_documents = text_splitter_eval.split_documents(eval_documents)

# %%
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

generator_llm = ChatOpenAI(model="gpt-3.5-turbo-16k")
critic_llm = ChatOpenAI(model="gpt-3.5-turbo")
embeddings = OpenAIEmbeddings()

generator = TestsetGenerator.from_langchain(
    generator_llm,
    critic_llm,
    embeddings
)

distributions = {
    simple: 0.5,
    multi_context: 0.4,
    reasoning: 0.1
}

testset = generator.generate_with_langchain_docs(eval_documents, 20, distributions, is_async = False)
testset.to_pandas()
# Out:
# embedding nodes:   0%|          | 0/2202 [00:00<?, ?it/s]
# Filename and doc_id are the same for all nodes.
# Generating:   0%|          | 0/20 [00:00<?, ?it/s]
#                                              question  \
# 0   What were the outcomes of the 2022 Restructuri...
# 1   How has the trading price of the Class A commo...
# 2   What is the authorized number of shares for Cl...
# 3   What is the amount of common stock issued acco...
# 4   What is the meaning of "terms and conditions" ...
# 5   What circumstances would not be considered a F...
# 6   From which countries did the majority of reven...
# 7   What is the significance of the reporting date...
# 8   What factors could lead to limited availabilit...
# 9   How could Delaware law and provisions in our c...
# 10  What is the purpose of our privacy risk manage...
# 11  What is the value of "Other assets" as of Dec ...
# 12  What is the authorized number of shares for Cl...
# 13  What accounting principles are used for Meta P...
# 14  What challenges does the company face regardin...
# 15  What legal challenges does the company face as...
# 16  What factors could harm our advertising busine...
# 17  How is diluted EPS for our common stock calcul...
# 18  How many data center projects were cancelled d...
# 19  How does the Arkansas Social Media Safety Act ...
#
#                                              contexts  \
# 0   [employees across the FoA and RL segments, and...
# 1   [The trading price of our Class A common stock...
# 2   [Table of Contents\nNote 13. Stockholders' Equ...
# 3   [2,614 \n— \n64,444 \n(3,530)\n64,799 \n125,71...
# 4   [U.S. federal securities laws in accordance wi...
# 5   [period.\nFor purposes of this Policy, a Finan...
# 6   [Accounts receivable are typically unsecured a...
# 7   [Table of Contents\n \n \nFair Value Measureme...
# 8   [•\nusers adopt new technologies where our pro...
# 9   [Delaware law and provisions in our certificat...
# 10  [on the overall operations of our cybersecurit...
# 11  [U.S. government securities\n8,708 \n8,708 \n—...
# 12  [Table of Contents\nNote 13. Stockholders' Equ...
# 13  [how the chief operating decision maker (CODM)...
# 14  [Table of Contents\nWe may incur liability as ...
# 15  [We believe that our facilities are adequate f...
# 16  [reduce our ability to effectively target ads,...
# 17  [The numerators and denominators of the basic ...
# 18  [employees across the FoA and RL segments, and...
# 19  [privacy and youth social media laws including...
#
#                                          ground_truth evolution_type  \
# 0   As of December 31, 2023, the outcomes of the 2...         simple
# 1   The trading price of our Class A common stock ...         simple
# 2   5,000 million shares of Class A common stock a...         simple
# 3                                                  65         simple
# 4                                                 nan         simple
# 5   An out-of-period adjustment that is immaterial...         simple
# 6   Western Europe, China, Brazil, Australia, Cana...         simple
# 7   The significance of the reporting date in fair...         simple
# 8                                                 nan         simple
# 9   Delaware law and provisions in the certificate...         simple
# 10  The purpose of our privacy risk management pro...  multi_context
# 11                                                101  multi_context
# 12  5,000 million shares of Class A common stock a...  multi_context
# 13  The consolidated financial statements of Meta ...  multi_context
# 14  We have faced, currently face, and will contin...  multi_context
# 15  As a multinational company, the company faces ...  multi_context
# 16  Our advertising revenue can be adversely affec...  multi_context
# 17  The diluted EPS for our common stock is calcul...  multi_context
# 18                                           multiple      reasoning
# 19                                                nan      reasoning
#
#                                              metadata  episode_done
# 0   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 1   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 2   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 3   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 4   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 5   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 6   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 7   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 8   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 9   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 10  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 11  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 12  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 13  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 14  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 15  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 16  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 17  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 18  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 19  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True

# %%
test_df = testset.to_pandas()

# %%
test_df
# Out:
#                                              question  \
# 0   What were the outcomes of the 2022 Restructuri...
# 1   How has the trading price of the Class A commo...
# 2   What is the authorized number of shares for Cl...
# 3   What is the amount of common stock issued acco...
# 4   What is the meaning of "terms and conditions" ...
# 5   What circumstances would not be considered a F...
# 6   From which countries did the majority of reven...
# 7   What is the significance of the reporting date...
# 8   What factors could lead to limited availabilit...
# 9   How could Delaware law and provisions in our c...
# 10  What is the purpose of our privacy risk manage...
# 11  What is the value of "Other assets" as of Dec ...
# 12  What is the authorized number of shares for Cl...
# 13  What accounting principles are used for Meta P...
# 14  What challenges does the company face regardin...
# 15  What legal challenges does the company face as...
# 16  What factors could harm our advertising busine...
# 17  How is diluted EPS for our common stock calcul...
# 18  How many data center projects were cancelled d...
# 19  How does the Arkansas Social Media Safety Act ...
#
#                                              contexts  \
# 0   [employees across the FoA and RL segments, and...
# 1   [The trading price of our Class A common stock...
# 2   [Table of Contents\nNote 13. Stockholders' Equ...
# 3   [2,614 \n— \n64,444 \n(3,530)\n64,799 \n125,71...
# 4   [U.S. federal securities laws in accordance wi...
# 5   [period.\nFor purposes of this Policy, a Finan...
# 6   [Accounts receivable are typically unsecured a...
# 7   [Table of Contents\n \n \nFair Value Measureme...
# 8   [•\nusers adopt new technologies where our pro...
# 9   [Delaware law and provisions in our certificat...
# 10  [on the overall operations of our cybersecurit...
# 11  [U.S. government securities\n8,708 \n8,708 \n—...
# 12  [Table of Contents\nNote 13. Stockholders' Equ...
# 13  [how the chief operating decision maker (CODM)...
# 14  [Table of Contents\nWe may incur liability as ...
# 15  [We believe that our facilities are adequate f...
# 16  [reduce our ability to effectively target ads,...
# 17  [The numerators and denominators of the basic ...
# 18  [employees across the FoA and RL segments, and...
# 19  [privacy and youth social media laws including...
#
#                                          ground_truth evolution_type  \
# 0   As of December 31, 2023, the outcomes of the 2...         simple
# 1   The trading price of our Class A common stock ...         simple
# 2   5,000 million shares of Class A common stock a...         simple
# 3                                                  65         simple
# 4                                                 nan         simple
# 5   An out-of-period adjustment that is immaterial...         simple
# 6   Western Europe, China, Brazil, Australia, Cana...         simple
# 7   The significance of the reporting date in fair...         simple
# 8                                                 nan         simple
# 9   Delaware law and provisions in the certificate...         simple
# 10  The purpose of our privacy risk management pro...  multi_context
# 11                                                101  multi_context
# 12  5,000 million shares of Class A common stock a...  multi_context
# 13  The consolidated financial statements of Meta ...  multi_context
# 14  We have faced, currently face, and will contin...  multi_context
# 15  As a multinational company, the company faces ...  multi_context
# 16  Our advertising revenue can be adversely affec...  multi_context
# 17  The diluted EPS for our common stock is calcul...  multi_context
# 18                                           multiple      reasoning
# 19                                                nan      reasoning
#
#                                              metadata  episode_done
# 0   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 1   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 2   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 3   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 4   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 5   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 6   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 7   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 8   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 9   [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 10  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 11  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 12  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 13  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 14  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 15  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 16  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 17  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 18  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True
# 19  [{'source': '/Users/SKTL/Desktop/Coding/VS-Cod...          True

# %%
test_questions = test_df["question"].values.tolist()
test_groundtruths = test_df["ground_truth"].values.tolist()

# %%
answers = []
contexts = []

for question in test_questions:
  response = retrieval_augmented_qa_chain.invoke({"question" : question})
  answers.append(response["response"].content)
  contexts.append([context.page_content for context in response["context"]])

# %%
from datasets import Dataset

response_dataset = Dataset.from_dict({
    "question" : test_questions,
    "answer" : answers,
    "contexts" : contexts,
    "ground_truth" : test_groundtruths
})

# %%
response_dataset[0]
# Out:
# {'question': 'What were the outcomes of the 2022 Restructuring in terms of data center projects and employee layoffs?',
#  'answer': 'The outcomes of the 2022 Restructuring were the completion of data center initiatives and employee layoffs.',
#  'contexts': ['(the 2022 Restructuring). As of December\xa031, 2023, we have completed the data center initiatives and the 2022 employee layoffs, and substantially completed\nthe facilities consolidation initiatives.',
#   '2023, we have completed the data center initiatives and the employee layoffs, and substantially completed the facilities consolidation initiatives.',
#   'Note\xa03. Restructuring\n2023 Restructuring\nIn March 2023, we announced three rounds of planned layoffs to further reduce our company size by approximately 10,000 employees across the Family',
#   'employees across the FoA and RL segments, and a pivot towards a next generation data center design, including cancellation of multiple data center projects'],
#  'ground_truth': 'As of December 31, 2023, the outcomes of the 2022 Restructuring were the completion of the data center initiatives and the employee layoffs.'}

# %%
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

# %%
results = evaluate(response_dataset, metrics)
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.

# %%
results
# Out:
# {'faithfulness': 0.7944, 'answer_relevancy': 0.6958, 'context_recall': 0.7150, 'context_precision': 0.7431, 'answer_correctness': 0.5698}

# %%
results_df = results.to_pandas()
results_df
# Out:
#                                              question  \
# 0   What were the outcomes of the 2022 Restructuri...
# 1   How has the trading price of the Class A commo...
# 2   What is the authorized number of shares for Cl...
# 3   What is the amount of common stock issued acco...
# 4   What is the meaning of "terms and conditions" ...
# 5   What circumstances would not be considered a F...
# 6   From which countries did the majority of reven...
# 7   What is the significance of the reporting date...
# 8   What factors could lead to limited availabilit...
# 9   How could Delaware law and provisions in our c...
# 10  What is the purpose of our privacy risk manage...
# 11  What is the value of "Other assets" as of Dec ...
# 12  What is the authorized number of shares for Cl...
# 13  What accounting principles are used for Meta P...
# 14  What challenges does the company face regardin...
# 15  What legal challenges does the company face as...
# 16  What factors could harm our advertising busine...
# 17  How is diluted EPS for our common stock calcul...
# 18  How many data center projects were cancelled d...
# 19  How does the Arkansas Social Media Safety Act ...
#
#                                                answer  \
# 0   The outcomes of the 2022 Restructuring were th...
# 1   The trading price of the Class A common stock ...
# 2   Class A: 5,000 million shares\nClass B: 4,141 ...
# 3                                       I don't know.
# 4                                       I don't know.
# 5   A revision of financial statements due to an e...
# 6   Western Europe, China, Brazil, Australia, Cana...
# 7   The significance of the reporting date in fair...
# 8   Government restrictions on access to Facebook ...
# 9   Delaware law and provisions in the certificate...
# 10  The purpose of our privacy risk management pro...
# 11                                      I don't know.
# 12  Authorized number of shares for Class A common...
# 13                                      I don't know.
# 14  The company faces challenges related to claims...
# 15  The company faces legal challenges such as num...
# 16  Factors that could harm the advertising busine...
# 17  The diluted EPS for common stock is calculated...
# 18  Multiple data center projects were cancelled d...
# 19                                      I don't know.
#
#                                              contexts  \
# 0   [(the 2022 Restructuring). As of December 31, ...
# 1   [The trading price of our Class A common stock...
# 2   [Stockholders' equity:\n \n \nCommon stock, $0...
# 3   [Stockholders' equity:\n \n \nCommon stock, $0...
# 4   [deemed to include the restrictions imposed he...
# 5   [period.\nFor purposes of this Policy, a Finan...
# 6   [States, with a majority of the revenue outsid...
# 7   [Table of Contents\n \n \nFair Value Measureme...
# 8   [•\nlimitations on our ability to offer a numb...
# 9   [Delaware law and provisions in our certificat...
# 10  [processes and programs to manage cybersecurit...
# 11  [2023\n2022\nAssets\n \n \nCurrent assets:\n \...
# 12  [shares issued and outstanding, as of December...
# 13  [statements include the accounts of Meta Platf...
# 14  [affect our business and financial results.\nW...
# 15  [Item 3. Legal Proceedings\nAs a multinational...
# 16  [financial results may be harmed.\nOur adverti...
# 17  [stock, while the diluted EPS of Class B commo...
# 18  [(the 2022 Restructuring). As of December 31, ...
# 19  [(CPRA), Arkansas Social Media Safety Act, Ohi...
#
#                                          ground_truth  faithfulness  \
# 0   As of December 31, 2023, the outcomes of the 2...      0.000000
# 1   The trading price of our Class A common stock ...      1.000000
# 2   5,000 million shares of Class A common stock a...      0.500000
# 3                                                  65           NaN
# 4                                                 nan           NaN
# 5   An out-of-period adjustment that is immaterial...      1.000000
# 6   Western Europe, China, Brazil, Australia, Cana...      0.166667
# 7   The significance of the reporting date in fair...      1.000000
# 8                                                 nan      1.000000
# 9   Delaware law and provisions in the certificate...      1.000000
# 10  The purpose of our privacy risk management pro...      1.000000
# 11                                                101           NaN
# 12  5,000 million shares of Class A common stock a...      1.000000
# 13  The consolidated financial statements of Meta ...           NaN
# 14  We have faced, currently face, and will contin...      0.750000
# 15  As a multinational company, the company faces ...      1.000000
# 16  Our advertising revenue can be adversely affec...      0.500000
# 17  The diluted EPS for our common stock is calcul...      1.000000
# 18                                           multiple      1.000000
# 19                                                nan           NaN
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           0.917656            1.00           0.916667            0.743913
# 1           0.979350            1.00           1.000000            0.846975
# 2           0.934909            1.00           1.000000            0.839575
# 3           0.000000            1.00           0.805556            0.193986
# 4           0.000000            0.00           0.000000            0.198202
# 5           0.929908            0.50           0.833333            0.582758
# 6           0.974979            1.00           1.000000            0.997174
# 7           0.999999            1.00           0.805556            0.619242
# 8           0.827966            0.80           0.000000            0.183517
# 9           0.895024            1.00           1.000000            0.607793
# 10          0.936471            1.00           1.000000            0.574370
# 11          0.000000            0.00           0.500000            0.195479
# 12          0.950373            0.50           0.500000            0.837555
# 13          0.000000            1.00           1.000000            0.180807
# 14          0.892450            0.25           1.000000            0.477186
# 15          0.923464            0.25           1.000000            0.833169
# 16          0.934001            1.00           1.000000            0.729415
# 17          0.910670            1.00           1.000000            0.621344
# 18          0.909661            1.00           0.500000            0.936047
# 19          0.000000            0.00           0.000000            0.198205

# %%
from langchain.retrievers import MultiQueryRetriever

advanced_retriever = MultiQueryRetriever.from_llm(retriever=retriever, llm=primary_qa_llm)

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain

document_chain = create_stuff_documents_chain(primary_qa_llm, retrieval_qa_prompt)

# %%
from langchain.chains import create_retrieval_chain

retrieval_chain = create_retrieval_chain(advanced_retriever, document_chain)

# %%
response = retrieval_chain.invoke({"input": "Who are Meta's 'Directors' (i.e., members of the Board of Directors)?"})

# %%
print(response["answer"])
# Out:
# The total value of 'Cash and cash equivalents' as of December 31, 2023, was $42,827 million.

# %%
response = retrieval_chain.invoke({"input": "Who are Meta's 'Directors' (i.e., members of the Board of Directors)?"})

# %%
print(response["answer"])
# Out:
# The members of the Board of Directors at Meta Platforms, Inc. are not explicitly mentioned in the provided context.
